# %%
pip install matplotlib pandas seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\desktop\task 3\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: pandas in c:\users\hp\desktop\task 3\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\hp\desktop\task 3\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\desktop\task 3\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data = {
    'Year': [2000, 2005, 2010, 2015, 2020],
    'income (USA)': [77, 78, 79, 79.5, 79.1],
    'income(Canada)': [79, 80, 81, 82, 82.5],
    'income (Germany)': [78, 79, 80, 81, 81.2]
}
df = pd.DataFrame(data)
df.set_index('Year', inplace=True)
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, palette="tab10", linewidth=2)
plt.title('income Over Time by Country')
plt.xlabel('income (Years)')
plt.ylabel('Year')
plt.legend(title='Country')
plt.show()
